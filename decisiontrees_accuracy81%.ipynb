# %% [markdown]
# <a href="https://colab.research.google.com/github/smishra9/Basic-practice/blob/main/decisiontrees_accuracy81%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib
# %matplotlib inline

# %%
titanic = pd.read_csv('/content/train.csv')

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ####We could clearly understand we can remove passengerid, ticket from dataset

# %%
titanic = titanic.drop(['PassengerId','Ticket'], axis =1)

# %%
titanic.head(2)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C

# %%
titanic = titanic.drop(['Name'], axis =1)

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
plt.scatter(titanic.SibSp,titanic.Survived)

# %%
titanic = titanic[titanic.SibSp<= 5]

# %%
plt.scatter(titanic.SibSp,titanic.Survived)

# %%
titanic.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         170
# SibSp         0
# Parch         0
# Fare          0
# Cabin       680
# Embarked      2
# dtype: int64

# %%
titanic= titanic.drop(['Cabin'], axis = 1)

# %%
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
data = titanic

# %%
plt.hist(titanic.Age)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
data =data.fillna(data.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  882 non-null    int64
#  1   Pclass    882 non-null    int64
#  2   Sex       882 non-null    object
#  3   Age       882 non-null    float64
#  4   SibSp     882 non-null    int64
#  5   Parch     882 non-null    int64
#  6   Fare      882 non-null    float64
#  7   Embarked  882 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 62.0+ KB

# %%
data.Embarked.value_counts()
# Out:
# S    637
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
adults = {'male':1,'female':0}
ad = data.Sex.map(adults)
data['Sex'] = ad

# %%
data
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3    1  22.000000      1      0   7.2500        S
# 1           1       1    0  38.000000      1      0  71.2833        C
# 2           1       3    0  26.000000      0      0   7.9250        S
# 3           1       1    0  35.000000      1      0  53.1000        S
# 4           0       3    1  35.000000      0      0   8.0500        S
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0       2    1  27.000000      0      0  13.0000        S
# 887         1       1    0  19.000000      0      0  30.0000        S
# 888         0       3    0  29.699118      1      2  23.4500        S
# 889         1       1    1  26.000000      0      0  30.0000        C
# 890         0       3    1  32.000000      0      0   7.7500        Q
#
# [882 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()

# %%
data['Embarked'] = model.fit_transform(data['Embarked'])

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %% [markdown]
# ####Dividing the data into training and test

# %%
from sklearn.model_selection import train_test_split
data_train,data_test= train_test_split(data,test_size = 0.25,random_state=42)

# %%
data_train.head()
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 601         0       3    1  29.699118      0      0   7.8958         2
# 521         0       3    1  22.000000      0      0   7.8958         2
# 452         0       1    1  30.000000      0      0  27.7500         0
# 819         0       3    1  10.000000      3      2  27.9000         2
# 772         0       2    0  57.000000      0      0  10.5000         2

# %%
data_test.head()
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 44          1       3    0  19.000000      0      0   7.8792         1
# 339         0       1    1  45.000000      0      0  35.5000         2
# 87          0       3    1  29.699118      0      0   8.0500         2
# 458         1       2    0  50.000000      0      0  10.5000         2
# 469         1       3    0   0.750000      2      1  19.2583         0

# %% [markdown]
# #####Creating dependent and independent variable

# %%
training_pred = data_train.drop(['Survived'], axis =1 )
training_target = data_train['Survived']
testing_pred = data_test.drop(['Survived'], axis =1 )
testing_target = data_test['Survived']

# %%
training_pred
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 601       3    1  29.699118      0      0   7.8958         2
# 521       3    1  22.000000      0      0   7.8958         2
# 452       1    1  30.000000      0      0  27.7500         0
# 819       3    1  10.000000      3      2  27.9000         2
# 772       2    0  57.000000      0      0  10.5000         2
# ..      ...  ...        ...    ...    ...      ...       ...
# 107       3    1  29.699118      0      0   7.7750         2
# 274       3    0  29.699118      0      0   7.7500         1
# 869       3    1   4.000000      1      1  11.1333         2
# 440       2    0  45.000000      1      1  26.2500         2
# 103       3    1  33.000000      0      0   8.6542         2
#
# [661 rows x 7 columns]

# %% [markdown]
# ####Importing decision tree

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier(criterion='entropy',max_depth= 9)

# %%
model.fit(training_pred,training_target)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=9)

# %%
model.score(training_pred,training_target)
# Out:
# 0.9046898638426626

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.43579545454545454, 0.95, 'X[1] <= 0.5\nentropy = 0.956\nsamples = 661\nvalue = [412, 249]'),
#  Text(0.20227272727272727, 0.85, 'X[0] <= 2.5\nentropy = 0.819\nsamples = 216\nvalue = [55, 161]'),
#  Text(0.05454545454545454, 0.75, 'X[2] <= 2.5\nentropy = 0.327\nsamples = 117\nvalue = [7, 110]'),
#  Text(0.03636363636363636, 0.65, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07272727272727272, 0.65, 'X[2] <= 24.5\nentropy = 0.294\nsamples = 116\nvalue = [6, 110]'),
#  Text(0.05454545454545454, 0.55, 'entropy = 0.0\nsamples = 37\nvalue = [0, 37]'),
#  Text(0.09090909090909091, 0.55, 'X[2] <= 27.5\nentropy = 0.388\nsamples = 79\nvalue = [6, 73]'),
#  Text(0.03636363636363636, 0.45, 'X[6] <= 1.0\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.01818181818181818, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05454545454545454, 0.35, 'X[5] <= 28.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.03636363636363636, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07272727272727272, 0.25, 'X[4] <= 1.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05454545454545454, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09090909090909091, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14545454545454545, 0.45, 'X[2] <= 43.5\nentropy = 0.245\nsamples = 74\nvalue = [3, 71]'),
#  Text(0.12727272727272726, 0.35, 'entropy = 0.0\nsamples = 47\nvalue = [0, 47]'),
#  Text(0.16363636363636364, 0.35, 'X[5] <= 34.156\nentropy = 0.503\nsamples = 27\nvalue = [3, 24]'),
#  Text(0.14545454545454545, 0.25, 'X[5] <= 28.217\nentropy = 0.779\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.12727272727272726, 0.15, 'X[0] <= 1.5\nentropy = 0.65\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.10909090909090909, 0.05, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.14545454545454545, 0.05, 'entropy = 0.811\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.16363636363636364, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18181818181818182, 0.25, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.35, 0.75, 'X[6] <= 1.5\nentropy = 0.999\nsamples = 99\nvalue = [48, 51]'),
#  Text(0.2727272727272727, 0.65, 'X[5] <= 14.852\nentropy = 0.732\nsamples = 39\nvalue = [8, 31]'),
#  Text(0.2545454545454545, 0.55, 'X[5] <= 13.935\nentropy = 0.863\nsamples = 28\nvalue = [8, 20]'),
#  Text(0.21818181818181817, 0.45, 'X[5] <= 6.987\nentropy = 0.575\nsamples = 22\nvalue = [3, 19]'),
#  Text(0.2, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23636363636363636, 0.35, 'X[4] <= 1.5\nentropy = 0.454\nsamples = 21\nvalue = [2, 19]'),
#  Text(0.21818181818181817, 0.25, 'X[2] <= 21.5\nentropy = 0.286\nsamples = 20\nvalue = [1, 19]'),
#  Text(0.2, 0.15, 'X[2] <= 18.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.18181818181818182, 0.05, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.21818181818181817, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23636363636363636, 0.15, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.2545454545454545, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2909090909090909, 0.45, 'X[2] <= 16.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.2727272727272727, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3090909090909091, 0.35, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2909090909090909, 0.55, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.42727272727272725, 0.65, 'X[5] <= 7.7\nentropy = 0.918\nsamples = 60\nvalue = [40, 20]'),
#  Text(0.4090909090909091, 0.55, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.44545454545454544, 0.55, 'X[5] <= 17.35\nentropy = 0.863\nsamples = 56\nvalue = [40, 16]'),
#  Text(0.38181818181818183, 0.45, 'X[5] <= 9.84\nentropy = 0.971\nsamples = 35\nvalue = [21, 14]'),
#  Text(0.34545454545454546, 0.35, 'X[4] <= 0.5\nentropy = 0.828\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.32727272727272727, 0.25, 'X[2] <= 54.0\nentropy = 0.773\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.3090909090909091, 0.15, 'X[5] <= 8.767\nentropy = 0.702\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.2909090909090909, 0.05, 'entropy = 0.837\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.32727272727272727, 0.05, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.34545454545454546, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36363636363636365, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41818181818181815, 0.35, 'X[2] <= 38.35\nentropy = 0.918\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.4, 0.25, 'X[4] <= 1.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.38181818181818183, 0.15, 'X[2] <= 28.85\nentropy = 0.918\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.36363636363636365, 0.05, 'entropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.4, 0.05, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.41818181818181815, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.43636363636363634, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.509090909090909, 0.45, 'X[2] <= 5.5\nentropy = 0.454\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.4909090909090909, 0.35, 'X[2] <= 3.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.4727272727272727, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.509090909090909, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5272727272727272, 0.35, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.6693181818181818, 0.85, 'X[2] <= 6.5\nentropy = 0.717\nsamples = 445\nvalue = [357, 88]'),
#  Text(0.5272727272727272, 0.75, 'X[3] <= 2.5\nentropy = 0.9\nsamples = 19\nvalue = [6, 13]'),
#  Text(0.509090909090909, 0.65, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.5454545454545454, 0.65, 'X[4] <= 1.5\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.5272727272727272, 0.55, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5636363636363636, 0.55, 'X[5] <= 31.331\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5454545454545454, 0.45, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5818181818181818, 0.45, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8113636363636364, 0.75, 'X[5] <= 26.269\nentropy = 0.671\nsamples = 426\nvalue = [351, 75]'),
#  Text(0.6954545454545454, 0.65, 'X[2] <= 13.5\nentropy = 0.53\nsamples = 324\nvalue = [285, 39]'),
#  Text(0.6363636363636364, 0.55, 'X[4] <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6181818181818182, 0.45, 'X[3] <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6363636363636364, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6545454545454545, 0.45, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7545454545454545, 0.55, 'X[5] <= 23.625\nentropy = 0.507\nsamples = 320\nvalue = [284, 36]'),
#  Text(0.7363636363636363, 0.45, 'X[6] <= 0.5\nentropy = 0.529\nsamples = 300\nvalue = [264, 36]'),
#  Text(0.6727272727272727, 0.35, 'X[5] <= 15.148\nentropy = 0.799\nsamples = 33\nvalue = [25, 8]'),
#  Text(0.6363636363636364, 0.25, 'X[2] <= 29.85\nentropy = 0.663\nsamples = 29\nvalue = [24, 5]'),
#  Text(0.6181818181818182, 0.15, 'X[5] <= 14.158\nentropy = 0.755\nsamples = 23\nvalue = [18, 5]'),
#  Text(0.6, 0.05, 'entropy = 0.811\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.6363636363636364, 0.05, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6545454545454545, 0.15, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.7090909090909091, 0.25, 'X[5] <= 20.233\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6909090909090909, 0.15, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7272727272727273, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.35, 'X[5] <= 22.887\nentropy = 0.484\nsamples = 267\nvalue = [239, 28]'),
#  Text(0.7818181818181819, 0.25, 'X[5] <= 13.25\nentropy = 0.474\nsamples = 266\nvalue = [239, 27]'),
#  Text(0.7636363636363637, 0.15, 'X[5] <= 7.91\nentropy = 0.515\nsamples = 235\nvalue = [208, 27]'),
#  Text(0.7454545454545455, 0.05, 'entropy = 0.369\nsamples = 127\nvalue = [118, 9]'),
#  Text(0.7818181818181819, 0.05, 'entropy = 0.65\nsamples = 108\nvalue = [90, 18]'),
#  Text(0.8, 0.15, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.8181818181818182, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7727272727272727, 0.45, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.9272727272727272, 0.65, 'X[3] <= 2.5\nentropy = 0.937\nsamples = 102\nvalue = [66, 36]'),
#  Text(0.9090909090909091, 0.55, 'X[2] <= 53.0\nentropy = 0.968\nsamples = 91\nvalue = [55, 36]'),
#  Text(0.8545454545454545, 0.45, 'X[5] <= 27.135\nentropy = 0.994\nsamples = 75\nvalue = [41, 34]'),
#  Text(0.8363636363636363, 0.35, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8727272727272727, 0.35, 'X[5] <= 379.925\nentropy = 0.964\nsamples = 67\nvalue = [41, 26]'),
#  Text(0.8545454545454545, 0.25, 'X[5] <= 134.642\nentropy = 0.95\nsamples = 65\nvalue = [41, 24]'),
#  Text(0.8363636363636363, 0.15, 'X[5] <= 115.442\nentropy = 0.967\nsamples = 61\nvalue = [37, 24]'),
#  Text(0.8181818181818182, 0.05, 'entropy = 0.953\nsamples = 59\nvalue = [37, 22]'),
#  Text(0.8545454545454545, 0.05, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8727272727272727, 0.15, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8909090909090909, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9636363636363636, 0.45, 'X[6] <= 1.0\nentropy = 0.544\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.9454545454545454, 0.35, 'X[3] <= 0.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.9272727272727272, 0.25, 'X[2] <= 57.0\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.9090909090909091, 0.15, 'X[5] <= 33.098\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8909090909090909, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9272727272727272, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9454545454545454, 0.15, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9636363636363636, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9818181818181818, 0.35, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.9454545454545454, 0.55, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]')]

# %%
label_test = model.predict(testing_pred)

# %%
from ssl import ALERT_DESCRIPTION_BAD_RECORD_MAC
from sklearn.metrics import accuracy_score
acc = accuracy_score(label_test,testing_target)

# %%
acc
# Out:
# 0.8054298642533937

# %% [markdown]
# ####We are achieving the accuracy of 81% which is pretty good according to the data
